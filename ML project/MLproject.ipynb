# %%
import pandas as pd
path="C:\\Users\\umraf\\OneDrive\\Desktop\\batch4\\Data\\Data\\train_data.csv"
data=pd.read_csv(path)
print(data)
print(data.info())
print(data.isnull().sum())
inputs=data.drop(['Orbit_type'],axis=1)
output=data['Orbit_type']
print(inputs)
print("******************************")
print(output)
print(data['Orbit_type'].unique())
import sklearn
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(inputs,output,train_size=0.8)
print(x_train)
print(x_test)
print(y_train)
print(y_test)
print("&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&")
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
from sklearn.svm import SVC
model=SVC()
model.fit(x_train,y_train) #
y_pred=model.predict(x_test)
import math
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)*100
print("acc:",math.ceil(acc))
#here we predict by our trained model for those test values tht we got before i.e used here for prediction
# here we compare the predicted values by our model after training WITH the givn data tht we got while spliting 
print(y_pred)
print(y_test)
print("###################################################################################################################")
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
print(cm)
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)*100
print("acc:",math.ceil(acc))
print("^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^")
import numpy as np
newip=np.array([[1,0,0,18.97,0.15,161,0.51,0,2459200.5,307.60489,254.74331,100.55712,22.99644,0.3182479,0.44670358,1.6948181,8,2459317.793,2.206402,1.1554458,2.2341904,0.761582,1.8289111]])
newip=sc.transform(newip)
res=model.predict(newip)
print(res)
# Out:
#        NEO_flag  One_km_NEO_flag  PHA_flag      H     G  Num_obs   rms  U  \
# 0             1                0         0  18.97  0.15      161  0.51  0
# 1             0                0         0  19.30  0.15       45  0.27  2
# 2             0                0         0  17.91  0.15      136  0.65  0
# 3             0                0         0  17.90  0.15      137  0.31  0
# 4             0                0         0  17.10  0.15       89  0.44  1
# ...         ...              ...       ...    ...   ...      ...   ... ..
# 79084         0                0         0  17.80  0.15       76  0.42  1
# 79085         0                0         0  17.43  0.15      273  0.52  0
# 79086         0                0         0  17.60  0.15      162  0.37  0
# 79087         0                0         0  16.90  0.15      321  0.52  0
# 79088         1                0         0  28.40  0.15       15  0.54  6
#
#            Epoch          M  ...         n         a  Num_opps           Tp  \
# ...
